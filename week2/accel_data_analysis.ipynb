# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV
df = pd.read_csv("accel_data.csv", header=None, names=["timestamp", "x", "y", "z"])

# Show first few rows
print("First 5 rows of the data:")
display(df.head())

# Basic statistics
print("\nBasic Statistics:")
display(df.describe())

# Plot acceleration data over time
plt.figure(figsize=(12,6))
plt.plot(df["timestamp"], df["x"], label="X-axis")
plt.plot(df["timestamp"], df["y"], label="Y-axis")
plt.plot(df["timestamp"], df["z"], label="Z-axis")
plt.xlabel("Timestamp")
plt.ylabel("Acceleration (g)")
plt.title("LSM6DS3 Acceleration Data Over Time")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# First 5 rows of the data:
#         timestamp       x       y       z
# 0  20250723205556  0.0702 -0.4823 -0.8618
# 1  20250723205556  0.0726 -0.4828 -0.8597
# 2  20250723205557  0.0756 -0.4835 -0.8594
# 3  20250723205558  0.0743 -0.4827 -0.8596
# 4  20250723205559  0.0728 -0.4812 -0.8600
# Basic Statistics:
#           timestamp            x            y            z
# count  1.808000e+03  1808.000000  1808.000000  1808.000000
# mean   2.025072e+13     0.075494    -0.416530    -0.891363
# std    2.008373e+03     0.002874     0.067052     0.030549
# min    2.025072e+13     0.061000    -0.493500    -0.948500
# 25%    2.025072e+13     0.073600    -0.481100    -0.926600
# 50%    2.025072e+13     0.075100    -0.452900    -0.876300
# 75%    2.025072e+13     0.077400    -0.340300    -0.861100
# max    2.025072e+13     0.090600    -0.306500    -0.843900
